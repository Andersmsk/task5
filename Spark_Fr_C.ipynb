# %%
import findspark
findspark.init()

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import max, avg, min
from pyspark.sql.functions import sum
from pyspark.sql.functions import when
from pyspark.sql.functions import count
from pyspark.sql.window import Window
from pyspark.sql.functions import desc
from pyspark.sql.functionimport findspark
findspark.init()s import expr
from pyspark.sql.functions import col, round, expr, dayofmonth, hour, minute, datediff, unix_timestamp

# %%
spark = SparkSession.builder \
    .config("spark.jars", "D:\Rep\INNOWISE\Study\TASK5\postgresql-42.6.0.jar") \
    .config("spark.driver.memory", "2g") \
    .config("spark.driver.memoryOverhead", "1g") \
    .appName("SqlToSpark") \
    .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://root:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>SqlToSpark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
url = "jdbc:postgresql://localhost:5432/postgres"

# %%
properties = {
    "user": "postgres",
    "password": "******",
    "driver": "org.postgresql.Driver"
}

# %%
film_df = spark.read.jdbc(url, "film", properties=properties)

# %%
film_category_df = spark.read.jdbc(url, "film_category", properties=properties)

# %%
actor_df = spark.read.jdbc(url, "actor", properties=properties)

# %%
film_actor_df = spark.read.jdbc(url, "film_actor", properties=properties)

# %%
category_df = spark.read.jdbc(url, "category", properties=properties)

# %%
inventory_df = spark.read.jdbc(url, "inventory", properties=properties)

# %%
rental_df = spark.read.jdbc(url, "rental", properties=properties)

# %%
payment_df = spark.read.jdbc(url, "payment", properties=properties)

# %%
city_df = spark.read.jdbc(url, "city", properties=properties)

# %%
address_df = spark.read.jdbc(url, "address", properties=properties)

# %%
customer_df = spark.read.jdbc(url, "customer", properties=properties)

# %%
# 1. Вывести количество фильмов в каждой категории, отсортировать по убыванию
films_in_category = film_df \
    .join(film_category_df, film_df.film_id == film_category_df.film_id) \
    .join(category_df, film_category_df.category_id == category_df.category_id) \
    .groupBy(category_df.name.alias("category_name")) \
    .count() \
    .orderBy("count", ascending=False)

# %%
films_in_category.show(truncate = False)
# Out:
# +-------------+-----+
# |category_name|count|
# +-------------+-----+
# |Sports       |74   |
# |Foreign      |73   |
# |Family       |69   |
# |Documentary  |68   |
# |Animation    |66   |
# |Action       |64   |
# |New          |63   |
# |Drama        |62   |
# |Games        |61   |
# |Sci-Fi       |61   |
# |Children     |60   |
# |Comedy       |58   |
# |Travel       |57   |
# |Classics     |57   |
# |Horror       |56   |
# |Music        |51   |
# +-------------+-----+

# %%
# 2. Вывести 10 актеров, чьи фильмы большего всего арендовали, отсортировать по убыванию
top_actors_rentals = actor_df \
    .join(film_actor_df, actor_df.actor_id == film_actor_df.actor_id) \
    .join(film_df, film_actor_df.film_id == film_df.film_id) \
    .join(inventory_df, film_df.film_id == inventory_df.film_id) \
    .join(rental_df, inventory_df.inventory_id == rental_df.inventory_id) \
    .filter(rental_df.return_date.isNotNull() & rental_df.rental_date.isNotNull()) \
    .withColumn("rental_duration", (rental_df.return_date - rental_df.rental_date)) \
    .selectExpr("CONCAT_WS(' ', COALESCE(first_name, ''), COALESCE(last_name, '')) AS actor_name", "rental_duration") \
    .orderBy("rental_duration", ascending=False) \
    .limit(10)

# %%
top_actors_rentals.show(truncate = False)
# Out:
# +----------------+----------------------------------------+
# |actor_name      |rental_duration                         |
# +----------------+----------------------------------------+
# |EWAN GOODING    |INTERVAL '39 05:41:03.968' DAY TO SECOND|
# |HUMPHREY GARLAND|INTERVAL '39 05:41:03.968' DAY TO SECOND|
# |JUDY DEAN       |INTERVAL '39 05:41:03.968' DAY TO SECOND|
# |GRACE MOSTEL    |INTERVAL '39 05:41:03.968' DAY TO SECOND|
# |MORGAN HOPKINS  |INTERVAL '39 05:41:03.968' DAY TO SECOND|
# |DARYL WAHLBERG  |INTERVAL '39 05:41:03.968' DAY TO SECOND|
# |RITA REYNOLDS   |INTERVAL '39 05:41:03.968' DAY TO SECOND|
# |CUBA ALLEN      |INTERVAL '39 05:41:03.968' DAY TO SECOND|
# |GARY PENN       |INTERVAL '39 01:45:45.884' DAY TO SECOND|
# |WARREN NOLTE    |INTERVAL '39 01:45:45.884' DAY TO SECOND|
# +----------------+----------------------------------------+

# %%
# 3. Вывести категорию фильмов, на которую потратили больше всего денег
category_spending = category_df \
    .join(film_category_df, category_df.category_id == film_category_df.category_id) \
    .join(film_df, film_category_df.film_id == film_df.film_id) \
    .join(inventory_df, film_df.film_id == inventory_df.film_id) \
    .join(rental_df, inventory_df.inventory_id == rental_df.inventory_id) \
    .join(payment_df, rental_df.rental_id == payment_df.rental_id) \
    .groupBy(category_df.name.alias("category_name")) \
    .sum("amount") \
    .orderBy("sum(amount)", ascending=False) \
    .limit(1)

# %%
category_spending.show(truncate = False)
# Out:
# +-------------+-----------+
# |category_name|sum(amount)|
# +-------------+-----------+
# |Sports       |17133.87   |
# +-------------+-----------+

# %%
# 4. Вывести названия фильмов, которых нет в inventory
missing_films = film_df \
    .join(inventory_df, film_df.film_id == inventory_df.film_id, "left") \
    .filter(inventory_df.film_id.isNull()) \
    .select(film_df.film_id, film_df.title) \
    .orderBy("title")

# %%
missing_films.show(50, truncate = False)
# Out:
# +-------+----------------------+
# |film_id|title                 |
# +-------+----------------------+
# |14     |ALICE FANTASIA        |
# |33     |APOLLO TEEN           |
# |36     |ARGONAUTS TOWN        |
# |38     |ARK RIDGEMONT         |
# |41     |ARSENIC INDEPENDENCE  |
# |87     |BOONDOCK BALLROOM     |
# |108    |BUTCH PANTHER         |
# |128    |CATCH AMISTAD         |
# |144    |CHINATOWN GLADIATOR   |
# |148    |CHOCOLATE DUCK        |
# |171    |COMMANDMENTS EXPRESS  |
# |192    |CROSSING DIVORCE      |
# |195    |CROWDS TELEMARK       |
# |198    |CRYSTAL BREAKING      |
# |217    |DAZED PUNK            |
# |221    |DELIVERANCE MULHOLLAND|
# |318    |FIREHOUSE VIETNAM     |
# |325    |FLOATS GARDEN         |
# |332    |FRANKENSTEIN STRANGER |
# |359    |GLADIATOR WESTWARD    |
# |386    |GUMP DATE             |
# |404    |HATE HANDICAP         |
# |419    |HOCUS FRIDA           |
# |495    |KENTUCKIAN GIANT      |
# |497    |KILL BROTHERHOOD      |
# |607    |MUPPET MILE           |
# |642    |ORDER BETRAYED        |
# |669    |PEARL DESTINY         |
# |671    |PERDITION FARGO       |
# |701    |PSYCHO SHRUNK         |
# |712    |RAIDERS ANTITRUST     |
# |713    |RAINBOW SHOCK         |
# |742    |ROOF CHAMPION         |
# |801    |SISTER FREDDY         |
# |802    |SKY MIRACLE           |
# |860    |SUICIDES SILENCE      |
# |874    |TADPOLE PARK          |
# |909    |TREASURE COMMAND      |
# |943    |VILLAIN DESPERATE     |
# |950    |VOLUME HOUSE          |
# |954    |WAKE JAWS             |
# |955    |WALLS ARTIST          |
# |1004   |WARRIORS              |
# +-------+----------------------+

# %%
# 5. Вывести топ 3 актеров, которые больше всего появлялись в фильмах в категории "Children"
top_actors_children = actor_df \
    .join(film_actor_df, actor_df.actor_id == film_actor_df.actor_id) \
    .join(film_df, film_actor_df.film_id == film_df.film_id) \
    .join(film_category_df, film_df.film_id == film_category_df.film_id) \
    .join(category_df, film_category_df.category_id == category_df.category_id) \
    .filter(category_df.name == "Children") \
    .groupBy(actor_df.actor_id, actor_df.first_name, actor_df.last_name) \
    .count() \
    .orderBy("count", ascending=False) \
    .limit(3)

# %%
top_actors_children.show(truncate = False)
# Out:
# +--------+----------+---------+-----+
# |actor_id|first_name|last_name|count|
# +--------+----------+---------+-----+
# |17      |HELEN     |VOIGHT   |7    |
# |127     |KEVIN     |GARLAND  |5    |
# |140     |WHOOPI    |HURT     |5    |
# +--------+----------+---------+-----+

# %%
# 6. Вывести города с количеством активных и неактивных клиентов
city_customers = city_df.join(address_df, city_df.city_id == address_df.city_id) \
    .join(customer_df, address_df.address_id == customer_df.address_id) \
    .groupBy(city_df.city.alias("city")) \
    .agg(
        sum(when(customer_df.active == 1, 1)).alias("active_customers"),
        sum(when(customer_df.active == 0, 1)).alias("inactive_customers")
    ) \
    .orderBy("inactive_customers", ascending=False)

# %%
city_customers.show(600, truncate = False)
# Out:
# +--------------------------+----------------+------------------+
# |city                      |active_customers|inactive_customers|
# +--------------------------+----------------+------------------+
# |Uluberia                  |null            |1                 |
# |Najafabad                 |null            |1                 |
# |Pingxiang                 |null            |1                 |
# |Xiangfan                  |null            |1                 |
# |Kumbakonam                |null            |1                 |
# |Szkesfehrvr               |null            |1                 |
# |Charlotte Amalie          |null            |1                 |
# |Kamyin                    |null            |1                 |
# |Daxian                    |null            |1                 |
# |Coatzacoalcos             |null            |1                 |
# |Wroclaw                   |null            |1                 |
# |Ktahya                    |null            |1                 |
# |Bat Yam                   |null            |1                 |
# |Southend-on-Sea           |null            |1                 |
# |Amroha                    |null            |1                 |
# |A Corua (La Corua)        |1               |null              |
# |Fengshan                  |1               |null              |
# |Chisinau                  |1               |null              |
# |Linz                      |1               |null              |
# |Udaipur                   |1               |null              |
# |El Alto                   |1               |null              |
# |Oyo                       |1               |null              |
# |Juiz de Fora              |1               |null              |
# |Sultanbeyli               |1               |null              |
# |Esfahan                   |1               |null              |
# |Monywa                    |1               |null              |
# |Jining                    |1               |null              |
# |Mit Ghamr                 |1               |null              |
# |Dhule (Dhulia)            |1               |null              |
# |Salzburg                  |1               |null              |
# |Tanauan                   |1               |null              |
# |Sogamoso                  |1               |null              |
# |Masqat                    |1               |null              |
# |Jastrzebie-Zdrj           |1               |null              |
# |Zhoushan                  |1               |null              |
# |Balaiha                   |1               |null              |
# |Faaa                      |1               |null              |
# |Compton                   |1               |null              |
# |Shubra al-Khayma          |1               |null              |
# |Lima                      |1               |null              |
# |Molodetno                 |1               |null              |
# |Guaruj                    |1               |null              |
# |Tongliao                  |1               |null              |
# |Rae Bareli                |1               |null              |
# |Kursk                     |1               |null              |
# |Shaoguan                  |1               |null              |
# |ostka                     |1               |null              |
# |Mysore                    |1               |null              |
# |Ondo                      |1               |null              |
# |Tiefa                     |1               |null              |
# |Shivapuri                 |1               |null              |
# |Novi Sad                  |1               |null              |
# |Anpolis                   |1               |null              |
# |Rampur                    |1               |null              |
# |Callao                    |1               |null              |
# |Fuyu                      |1               |null              |
# |Sirjan                    |1               |null              |
# |Inegl                     |1               |null              |
# |Vitria de Santo Anto      |1               |null              |
# |Lungtan                   |1               |null              |
# |Coquimbo                  |1               |null              |
# |Amersfoort                |1               |null              |
# |Greensboro                |1               |null              |
# |Dallas                    |1               |null              |
# |Uttarpara-Kotrung         |1               |null              |
# |Adana                     |1               |null              |
# |Syrakusa                  |1               |null              |
# |Batman                    |1               |null              |
# |Manchester                |1               |null              |
# |Laredo                    |1               |null              |
# |Bradford                  |1               |null              |
# |La Romana                 |1               |null              |
# |Jakarta                   |1               |null              |
# |Jedda                     |1               |null              |
# |Nagaon                    |1               |null              |
# |Fontana                   |1               |null              |
# |Palghat (Palakkad)        |1               |null              |
# |Tianjin                   |1               |null              |
# |Jos Azueta                |1               |null              |
# |Lipetsk                   |1               |null              |
# |Toulon                    |1               |null              |
# |Abha                      |1               |null              |
# |Ruse                      |1               |null              |
# |Ueda                      |1               |null              |
# |Benguela                  |1               |null              |
# |Gulbarga                  |1               |null              |
# |Kamarhati                 |1               |null              |
# |Bern                      |1               |null              |
# |Juazeiro do Norte         |1               |null              |
# |Changhwa                  |1               |null              |
# |Sivas                     |1               |null              |
# |Donostia-San Sebastin     |1               |null              |
# |Siegen                    |1               |null              |
# |Tsaotun                   |1               |null              |
# |Bucuresti                 |1               |null              |
# |Jodhpur                   |1               |null              |
# |Dayton                    |1               |null              |
# |Tabuk                     |1               |null              |
# |Kanazawa                  |1               |null              |
# |Arak                      |1               |null              |
# |Mandi Bahauddin           |1               |null              |
# |Salala                    |1               |null              |
# |Tete                      |1               |null              |
# |Birgunj                   |1               |null              |
# |Lhokseumawe               |1               |null              |
# |Haldia                    |1               |null              |
# |Siliguri (Shiliguri)      |1               |null              |
# |Nezahualcyotl             |1               |null              |
# |Zanzibar                  |1               |null              |
# |Matamoros                 |1               |null              |
# |Livorno                   |1               |null              |
# |Jhansi                    |1               |null              |
# |Pyongyang                 |1               |null              |
# |Yinchuan                  |1               |null              |
# |Niznekamsk                |1               |null              |
# |Kragujevac                |1               |null              |
# |Papeete                   |1               |null              |
# |Tanza                     |1               |null              |
# |Bayugan                   |1               |null              |
# |Botosani                  |1               |null              |
# |Moscow                    |1               |null              |
# |Kirovo-Tepetsk            |1               |null              |
# |Kurgan                    |1               |null              |
# |Bhavnagar                 |1               |null              |
# |Nukualofa                 |1               |null              |
# |Halle/Saale               |1               |null              |
# |Carmen                    |1               |null              |
# |Kamjanets-Podilskyi       |1               |null              |
# |Nha Trang                 |1               |null              |
# |Shahr-e Kord              |1               |null              |
# |Caracas                   |1               |null              |
# |Citt del Vaticano         |1               |null              |
# |Konotop                   |1               |null              |
# |Adoni                     |1               |null              |
# |Fuzhou                    |1               |null              |
# |Boksburg                  |1               |null              |
# |Ahmadnagar                |1               |null              |
# |Clarksville               |1               |null              |
# |Ede                       |1               |null              |
# |Coacalco de Berriozbal    |1               |null              |
# |Sharja                    |1               |null              |
# |Hidalgo                   |1               |null              |
# |Jinchang                  |1               |null              |
# |Angra dos Reis            |1               |null              |
# |Hubli-Dharwad             |1               |null              |
# |Probolinggo               |1               |null              |
# |Atinsk                    |1               |null              |
# |Hunuco                    |1               |null              |
# |Dundee                    |1               |null              |
# |Rockford                  |1               |null              |
# |Tandil                    |1               |null              |
# |Pemalang                  |1               |null              |
# |Kurashiki                 |1               |null              |
# |Dos Quebradas             |1               |null              |
# |Kuwana                    |1               |null              |
# |Portoviejo                |1               |null              |
# |Pereira                   |1               |null              |
# |Lubumbashi                |1               |null              |
# |Santa Rosa                |1               |null              |
# |Shikarpur                 |1               |null              |
# |Ranchi                    |1               |null              |
# |Augusta-Richmond County   |1               |null              |
# |Elista                    |1               |null              |
# |Effon-Alaiye              |1               |null              |
# |Po                        |1               |null              |
# |Oulu                      |1               |null              |
# |London                    |2               |null              |
# |Tarsus                    |1               |null              |
# |Pontianak                 |1               |null              |
# |Tallahassee               |1               |null              |
# |Mandaluyong               |1               |null              |
# |Aurora                    |2               |null              |
# |Koriyama                  |1               |null              |
# |Minsk                     |4               |null              |
# |Addis Abeba               |1               |null              |
# |Ashdod                    |1               |null              |
# |Pachuca de Soto           |1               |null              |
# |Richmond Hill             |1               |null              |
# |Bergamo                   |1               |null              |
# |Hino                      |1               |null              |
# |Sucre                     |1               |null              |
# |Tabora                    |1               |null              |
# |Garden Grove              |1               |null              |
# |Etawah                    |1               |null              |
# |So Bernardo do Campo      |1               |null              |
# |Tangail                   |1               |null              |
# |Taizz                     |1               |null              |
# |Daugavpils                |1               |null              |
# |Graz                      |1               |null              |
# |South Hill                |1               |null              |
# |Yerevan                   |1               |null              |
# |Tokat                     |1               |null              |
# |Novoterkassk              |1               |null              |
# |Jaffna                    |1               |null              |
# |Bamenda                   |1               |null              |
# |Boa Vista                 |1               |null              |
# |Kamakura                  |1               |null              |
# |Battambang                |1               |null              |
# |Parbhani                  |1               |null              |
# |Luzinia                   |1               |null              |
# |Arecibo                   |1               |null              |
# |Buenaventura              |1               |null              |
# |Nantou                    |1               |null              |
# |Memphis                   |1               |null              |
# |Firozabad                 |1               |null              |
# |Soshanguve                |1               |null              |
# |Berhampore (Baharampur)   |1               |null              |
# |Kisumu                    |1               |null              |
# |Tabriz                    |1               |null              |
# |Okayama                   |1               |null              |
# |Brockton                  |1               |null              |
# |Oshawa                    |1               |null              |
# |Ciomas                    |1               |null              |
# |Naju                      |1               |null              |
# |Otsu                      |1               |null              |
# |Kolpino                   |1               |null              |
# |Zhezqazghan               |1               |null              |
# |Funafuti                  |1               |null              |
# |Korla                     |1               |null              |
# |Merlo                     |1               |null              |
# |al-Hawiya                 |1               |null              |
# |Lausanne                  |1               |null              |
# |Cam Ranh                  |1               |null              |
# |Erlangen                  |1               |null              |
# |Monclova                  |1               |null              |
# |Cuernavaca                |1               |null              |
# |Mardan                    |1               |null              |
# |Brindisi                  |1               |null              |
# |Maracabo                  |1               |null              |
# |Mexicali                  |1               |null              |
# |Usak                      |1               |null              |
# |Beira                     |1               |null              |
# |Smolensk                  |1               |null              |
# |Poos de Caldas            |1               |null              |
# |Bijapur                   |1               |null              |
# |Garland                   |1               |null              |
# |Maring                    |1               |null              |
# |Nador                     |1               |null              |
# |Leshan                    |1               |null              |
# |Tel Aviv-Jaffa            |1               |null              |
# |Nabereznyje Telny         |1               |null              |
# |Higashiosaka              |1               |null              |
# |Baku                      |1               |null              |
# |Escobar                   |1               |null              |
# |Balikesir                 |1               |null              |
# |Syktyvkar                 |1               |null              |
# |Warren                    |1               |null              |
# |Tuguegarao                |1               |null              |
# |Kowloon and New Kowloon   |1               |null              |
# |Cuman                     |1               |null              |
# |Ashqelon                  |1               |null              |
# |Nam Dinh                  |1               |null              |
# |Cheju                     |1               |null              |
# |Loja                      |1               |null              |
# |Kimchon                   |1               |null              |
# |Zalantun                  |1               |null              |
# |So Leopoldo               |1               |null              |
# |Alessandria               |1               |null              |
# |Klerksdorp                |1               |null              |
# |Baha Blanca               |1               |null              |
# |Taguig                    |1               |null              |
# |Zeleznogorsk              |1               |null              |
# |Binzhou                   |1               |null              |
# |Kalisz                    |1               |null              |
# |Mahajanga                 |1               |null              |
# |El Fuerte                 |1               |null              |
# |Duisburg                  |1               |null              |
# |Huaian                    |1               |null              |
# |Florencia                 |1               |null              |
# |Osmaniye                  |1               |null              |
# |Cianjur                   |1               |null              |
# |Fukuyama                  |1               |null              |
# |Songkhla                  |1               |null              |
# |Junan                     |1               |null              |
# |Jamalpur                  |1               |null              |
# |Vicente Lpez              |1               |null              |
# |Asuncin                   |1               |null              |
# |Korolev                   |1               |null              |
# |Barcelona                 |1               |null              |
# |Ozamis                    |1               |null              |
# |Celaya                    |1               |null              |
# |Sterling Heights          |1               |null              |
# |Davao                     |1               |null              |
# |Nagareyama                |1               |null              |
# |Lancaster                 |1               |null              |
# |Katihar                   |1               |null              |
# |San Felipe del Progreso   |1               |null              |
# |Kitwe                     |1               |null              |
# |Hodeida                   |1               |null              |
# |Bandar Seri Begawan       |1               |null              |
# |Citrus Heights            |1               |null              |
# |Kilis                     |1               |null              |
# |San Lorenzo               |1               |null              |
# |Sorocaba                  |1               |null              |
# |Guadalajara               |1               |null              |
# |Haining                   |1               |null              |
# |Jalib al-Shuyukh          |1               |null              |
# |Pudukkottai               |1               |null              |
# |Ljubertsy                 |1               |null              |
# |Datong                    |1               |null              |
# |Cabuyao                   |1               |null              |
# |Bhimavaram                |1               |null              |
# |Bydgoszcz                 |1               |null              |
# |Akron                     |1               |null              |
# |Udine                     |1               |null              |
# |Allappuzha (Alleppey)     |1               |null              |
# |Suihua                    |1               |null              |
# |Sullana                   |1               |null              |
# |Lapu-Lapu                 |1               |null              |
# |Izumisano                 |1               |null              |
# |Acua                      |1               |null              |
# |Omiya                     |1               |null              |
# |Belm                      |1               |null              |
# |Talavera                  |1               |null              |
# |Chandrapur                |1               |null              |
# |Akishima                  |1               |null              |
# |Ponce                     |1               |null              |
# |Lincoln                   |1               |null              |
# |Kabul                     |1               |null              |
# |Grand Prairie             |1               |null              |
# |s-Hertogenbosch           |1               |null              |
# |Vancouver                 |1               |null              |
# |Qalyub                    |1               |null              |
# |Cavite                    |1               |null              |
# |Olomouc                   |1               |null              |
# |Tambaram                  |1               |null              |
# |Okara                     |1               |null              |
# |Laiwu                     |1               |null              |
# |Beni-Mellal               |1               |null              |
# |Hsichuh                   |1               |null              |
# |Arlington                 |1               |null              |
# |Baiyin                    |1               |null              |
# |Aden                      |1               |null              |
# |Mogiljov                  |1               |null              |
# |Banjul                    |1               |null              |
# |Rustenburg                |1               |null              |
# |Haiphong                  |1               |null              |
# |Pangkal Pinang            |1               |null              |
# |Meixian                   |1               |null              |
# |Lublin                    |1               |null              |
# |Araatuba                  |1               |null              |
# |Aparecida de Goinia       |1               |null              |
# |Kakamigahara              |1               |null              |
# |Mannheim                  |1               |null              |
# |Bchar                     |1               |null              |
# |Goinia                    |1               |null              |
# |Yuncheng                  |1               |null              |
# |Gandhinagar               |1               |null              |
# |Pak Kret                  |1               |null              |
# |Sokoto                    |1               |null              |
# |Ikerre                    |1               |null              |
# |Weifang                   |1               |null              |
# |Tonghae                   |1               |null              |
# |Avellaneda                |1               |null              |
# |Ife                       |1               |null              |
# |Chapra                    |1               |null              |
# |Hagonoy                   |1               |null              |
# |Nakhon Sawan              |1               |null              |
# |Santa F                   |1               |null              |
# |Patiala                   |1               |null              |
# |Idfu                      |1               |null              |
# |Sincelejo                 |1               |null              |
# |Simferopol                |1               |null              |
# |Zapopan                   |1               |null              |
# |Sanaa                     |1               |null              |
# |Jinzhou                   |1               |null              |
# |Serpuhov                  |1               |null              |
# |Matsue                    |1               |null              |
# |Pjatigorsk                |1               |null              |
# |Xinxiang                  |1               |null              |
# |Ezeiza                    |1               |null              |
# |Pathankot                 |1               |null              |
# |Braslia                   |1               |null              |
# |Kingstown                 |1               |null              |
# |Xintai                    |1               |null              |
# |Crdoba                    |1               |null              |
# |Gijn                      |1               |null              |
# |Sunnyvale                 |1               |null              |
# |Qomsheh                   |1               |null              |
# |Botshabelo                |1               |null              |
# |Purnea (Purnia)           |1               |null              |
# |La Plata                  |1               |null              |
# |Southport                 |1               |null              |
# |Southampton               |1               |null              |
# |Liaocheng                 |1               |null              |
# |Laohekou                  |1               |null              |
# |Pune                      |1               |null              |
# |Johannesburg              |1               |null              |
# |Santiago de Compostela    |1               |null              |
# |Kimberley                 |1               |null              |
# |Bilbays                   |1               |null              |
# |Vaduz                     |1               |null              |
# |Alvorada                  |1               |null              |
# |Lengshuijiang             |1               |null              |
# |Toulouse                  |1               |null              |
# |Saarbrcken                |1               |null              |
# |Uruapan                   |1               |null              |
# |San Felipe de Puerto Plata|1               |null              |
# |Urawa                     |1               |null              |
# |Gatineau                  |1               |null              |
# |Cuautla                   |1               |null              |
# |Bag                       |1               |null              |
# |Touliu                    |1               |null              |
# |Usolje-Sibirskoje         |1               |null              |
# |Chungho                   |1               |null              |
# |Hoshiarpur                |1               |null              |
# |Ciudad del Este           |1               |null              |
# |Kansas City               |1               |null              |
# |Hanoi                     |1               |null              |
# |Patras                    |1               |null              |
# |Stara Zagora              |1               |null              |
# |Salinas                   |1               |null              |
# |al-Qatif                  |1               |null              |
# |Tama                      |1               |null              |
# |Denizli                   |1               |null              |
# |Sambhal                   |1               |null              |
# |Owo                       |1               |null              |
# |Ourense (Orense)          |1               |null              |
# |Saint-Denis               |1               |null              |
# |Bhopal                    |1               |null              |
# |Shimonoseki               |1               |null              |
# |Abu Dhabi                 |1               |null              |
# |Eskisehir                 |1               |null              |
# |Allende                   |1               |null              |
# |Stockport                 |1               |null              |
# |Purwakarta                |1               |null              |
# |Saint Louis               |1               |null              |
# |Naala-Porto               |1               |null              |
# |Yuzhou                    |1               |null              |
# |Valle de la Pascua        |1               |null              |
# |Yantai                    |1               |null              |
# |Yangor                    |1               |null              |
# |Bratislava                |1               |null              |
# |Hamilton                  |1               |null              |
# |Blumenau                  |1               |null              |
# |Isesaki                   |1               |null              |
# |Almirante Brown           |1               |null              |
# |Valparai                  |1               |null              |
# |Sousse                    |1               |null              |
# |Karnal                    |1               |null              |
# |Tegal                     |1               |null              |
# |Kermanshah                |1               |null              |
# |Mosul                     |1               |null              |
# |Hami                      |1               |null              |
# |Emmen                     |1               |null              |
# |Ambattur                  |1               |null              |
# |Dongying                  |1               |null              |
# |Vinh                      |1               |null              |
# |Roanoke                   |1               |null              |
# |Czestochowa               |1               |null              |
# |Peoria                    |1               |null              |
# |Gaziantep                 |1               |null              |
# |Tafuna                    |1               |null              |
# |Imus                      |1               |null              |
# |Qinhuangdao               |1               |null              |
# |Maikop                    |1               |null              |
# |La Paz                    |1               |null              |
# |Tarlac                    |1               |null              |
# |Kaliningrad               |1               |null              |
# |Cayenne                   |1               |null              |
# |Sal                       |1               |null              |
# |Iwatsuki                  |1               |null              |
# |Skikda                    |1               |null              |
# |Vilnius                   |1               |null              |
# |Ibirit                    |1               |null              |
# |Cape Coral                |1               |null              |
# |Pavlodar                  |1               |null              |
# |Chatsworth                |1               |null              |
# |Ilorin                    |1               |null              |
# |Ezhou                     |1               |null              |
# |Torren                    |1               |null              |
# |Yamuna Nagar              |1               |null              |
# |Ogbomosho                 |1               |null              |
# |Ciparay                   |1               |null              |
# |Bellevue                  |1               |null              |
# |Deba Habe                 |1               |null              |
# |Liepaja                   |1               |null              |
# |Zaria                     |1               |null              |
# |Antofagasta               |1               |null              |
# |Brest                     |1               |null              |
# |Mwanza                    |1               |null              |
# |al-Qadarif                |1               |null              |
# |Changzhou                 |1               |null              |
# |Lilongwe                  |1               |null              |
# |Valencia                  |1               |null              |
# |Paarl                     |1               |null              |
# |Hohhot                    |1               |null              |
# |Zaoyang                   |1               |null              |
# |Chiayi                    |1               |null              |
# |Vila Velha                |1               |null              |
# |Shenzhen                  |1               |null              |
# |Malm                      |1               |null              |
# |Sagamihara                |1               |null              |
# |Rizhao                    |1               |null              |
# |Cuauhtmoc                 |1               |null              |
# |Dzerzinsk                 |1               |null              |
# |Bhilwara                  |1               |null              |
# |Valle de Santiago         |1               |null              |
# |Sumy                      |1               |null              |
# |Santo Andr                |1               |null              |
# |Madiun                    |1               |null              |
# |Batna                     |1               |null              |
# |Rajkot                    |1               |null              |
# |Springs                   |1               |null              |
# |guas Lindas de Gois       |1               |null              |
# |Mwene-Ditu                |1               |null              |
# |Sungai Petani             |1               |null              |
# |Tanshui                   |1               |null              |
# |Basel                     |1               |null              |
# |San Miguel de Tucumn      |1               |null              |
# |Kaduna                    |1               |null              |
# |Miraj                     |1               |null              |
# |NDjamna                   |1               |null              |
# |Atlixco                   |1               |null              |
# |Sawhaj                    |1               |null              |
# |Bhusawal                  |1               |null              |
# |Vijayawada                |1               |null              |
# |Mukateve                  |1               |null              |
# |Ocumare del Tuy           |1               |null              |
# |Okinawa                   |1               |null              |
# |Jurez                     |1               |null              |
# |Sanya                     |1               |null              |
# |Satna                     |1               |null              |
# |Gorontalo                 |1               |null              |
# |Namibe                    |1               |null              |
# |Rancagua                  |1               |null              |
# |Surakarta                 |1               |null              |
# |Yingkou                   |1               |null              |
# |Rio Claro                 |1               |null              |
# |Kuching                   |1               |null              |
# |Uijongbu                  |1               |null              |
# |Yaound                    |1               |null              |
# |Newcastle                 |1               |null              |
# |Tartu                     |1               |null              |
# |al-Ayn                    |1               |null              |
# |Enshi                     |1               |null              |
# |Jaroslavl                 |1               |null              |
# |Joliet                    |1               |null              |
# |Munger (Monghyr)          |1               |null              |
# |Huejutla de Reyes         |1               |null              |
# |Quilmes                   |1               |null              |
# |Shimoga                   |1               |null              |
# |Sumqayit                  |1               |null              |
# |Witten                    |1               |null              |
# |Shanwei                   |1               |null              |
# |Plock                     |1               |null              |
# |Baybay                    |1               |null              |
# |Emeishan                  |1               |null              |
# |Baicheng                  |1               |null              |
# |Santa Brbara dOeste       |1               |null              |
# |Iligan                    |1               |null              |
# |Ziguinchor                |1               |null              |
# |Hiroshima                 |1               |null              |
# |Iwakuni                   |1               |null              |
# |Tsuyama                   |1               |null              |
# |Ashgabat                  |1               |null              |
# |al-Manama                 |1               |null              |
# |Phnom Penh                |1               |null              |
# |Apeldoorn                 |1               |null              |
# |Huixquilucan              |1               |null              |
# |El Monte                  |1               |null              |
# |Ivanovo                   |1               |null              |
# |Trshavn                   |1               |null              |
# |Xiangtan                  |1               |null              |
# |Kanchrapara               |1               |null              |
# |Jaipur                    |1               |null              |
# |Balurghat                 |1               |null              |
# |Onomichi                  |1               |null              |
# |Halisahar                 |1               |null              |
# |Halifax                   |1               |null              |
# |Tychy                     |1               |null              |
# |York                      |1               |null              |
# |Nanyang                   |1               |null              |
# |Robamba                   |1               |null              |
# |Miyakonojo                |1               |null              |
# |Salamanca                 |1               |null              |
# |Iwaki                     |1               |null              |
# |Dadu                      |1               |null              |
# |Ipoh                      |1               |null              |
# |Gingoog                   |1               |null              |
# |Benin City                |1               |null              |
# |Le Mans                   |1               |null              |
# |Dhaka                     |1               |null              |
# |Nuuk                      |1               |null              |
# |Tieli                     |1               |null              |
# |Bislig                    |1               |null              |
# |Omdurman                  |1               |null              |
# |Varanasi (Benares)        |1               |null              |
# |Nyeri                     |1               |null              |
# |San Juan Bautista Tuxtepec|1               |null              |
# |Brescia                   |1               |null              |
# |Teboksary                 |1               |null              |
# |Jelets                    |1               |null              |
# |Santiago de los Caballeros|1               |null              |
# +--------------------------+----------------+------------------+

# %%
# 7. Вывести категорию фильмов с самым большим количеством часов суммарной аренды в городах, начинающихся на "a"
#    и содержащих символ "-"

query = """
SELECT c.name,
       CAST((EXTRACT(EPOCH FROM (r.return_date - r.rental_date)) / 3600) AS INT) AS rental_duration_in_hours,
       c3.city
FROM category c
INNER JOIN film_category fc ON c.category_id = fc.category_id
INNER JOIN film f ON fc.film_id = f.film_id
INNER JOIN inventory i ON f.film_id = i.film_id
INNER JOIN rental r ON i.inventory_id = r.inventory_id
INNER JOIN customer c2 ON r.customer_id = c2.customer_id
INNER JOIN address a ON c2.address_id = a.address_id
INNER JOIN city c3 ON a.city_id = c3.city_id
WHERE (r.return_date IS NOT NULL AND r.rental_date IS NOT NULL
       AND c3.city LIKE 'a%')
      OR (r.return_date IS NOT NULL AND r.rental_date IS NOT NULL
          AND c3.city LIKE '%-%')
ORDER BY rental_duration_in_hours DESC
"""

film_cat_filtered = spark.read.jdbc(url, "(%s) AS tmp" % query, properties=properties)

# %%
film_cat_filtered.show(truncate = False)
# Out:
# +-----------+------------------------+-----------------+
# |name       |rental_duration_in_hours|city             |
# +-----------+------------------------+-----------------+
# |Action     |936                     |Lapu-Lapu        |
# |Documentary|935                     |al-Hawiya        |
# |Horror     |932                     |Naala-Porto      |
# |Sports     |923                     |Shubra al-Khayma |
# |Sports     |922                     |Jalib al-Shuyukh |
# |Drama      |922                     |Lapu-Lapu        |
# |Drama      |902                     |Effon-Alaiye     |
# |Comedy     |899                     |Shubra al-Khayma |
# |Music      |897                     |Uttarpara-Kotrung|
# |Sci-Fi     |893                     |Jastrzebie-Zdrj  |
# |Classics   |890                     |Usolje-Sibirskoje|
# |Action     |888                     |Saint-Denis      |
# |Drama      |884                     |Lapu-Lapu        |
# |Foreign    |882                     |Naala-Porto      |
# |Comedy     |872                     |Lapu-Lapu        |
# |Games      |868                     |Saint-Denis      |
# |Travel     |859                     |Saint-Denis      |
# |Foreign    |858                     |al-Ayn           |
# |Travel     |855                     |al-Ayn           |
# |Family     |854                     |Shubra al-Khayma |
# +-----------+------------------------+-----------------+
# only showing top 20 rows

# %%
film_cat_filtered_2 = category_df \
    .join(film_category_df, category_df.category_id == film_category_df.category_id) \
    .join(film_df, film_category_df.film_id == film_df.film_id) \
    .join(inventory_df, film_df.film_id == inventory_df.film_id) \
    .join(rental_df, inventory_df.inventory_id == rental_df.inventory_id) \
    .join(customer_df, rental_df.customer_id == customer_df.customer_id) \
    .join(address_df, customer_df.address_id == address_df.address_id) \
    .join(city_df, address_df.city_id == city_df.city_id) \
    .filter((rental_df.return_date.isNotNull()) & (rental_df.rental_date.isNotNull()) &
            ((city_df.city.like('a%')) | (city_df.city.like('%-%')))) \
    .select(category_df.name.alias('name'),
            round((unix_timestamp(rental_df.return_date) - unix_timestamp(rental_df.rental_date)) / 3600)
            .alias('rental_duration_in_hours'),
            city_df.city) \
    .orderBy(expr('rental_duration_in_hours').desc())

# %%
film_cat_filtered_2.show()
# Out:
# +-----------+------------------------+-----------------+
# |       name|rental_duration_in_hours|             city|
# +-----------+------------------------+-----------------+
# |     Action|                   936.0|        Lapu-Lapu|
# |Documentary|                   935.0|        al-Hawiya|
# |     Horror|                   932.0|      Naala-Porto|
# |     Sports|                   923.0| Shubra al-Khayma|
# |     Sports|                   922.0| Jalib al-Shuyukh|
# |      Drama|                   922.0|        Lapu-Lapu|
# |      Drama|                   902.0|     Effon-Alaiye|
# |     Comedy|                   899.0| Shubra al-Khayma|
# |      Music|                   897.0|Uttarpara-Kotrung|
# |     Sci-Fi|                   893.0|  Jastrzebie-Zdrj|
# |   Classics|                   890.0|Usolje-Sibirskoje|
# |     Action|                   888.0|      Saint-Denis|
# |      Drama|                   884.0|        Lapu-Lapu|
# |    Foreign|                   882.0|      Naala-Porto|
# |     Comedy|                   872.0|        Lapu-Lapu|
# |      Games|                   868.0|      Saint-Denis|
# |     Travel|                   859.0|      Saint-Denis|
# |    Foreign|                   858.0|           al-Ayn|
# |     Travel|                   855.0|           al-Ayn|
# |     Family|                   854.0| Shubra al-Khayma|
# +-----------+------------------------+-----------------+
# only showing top 20 rows

# %%
SparkSession.stop(spark)
